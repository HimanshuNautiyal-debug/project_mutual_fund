# %%
from sqlalchemy import create_engine,text
import pandas as pd

# %%
engine = create_engine("sqlite:///project")

# %%
top_5_funda_by_aum = text("""
             select fund_name, sum(aum) as total_aum from fact_aum fa
             join dim_fund df on fa.find_id = df.fund_id
             group by fund_name 
             order by total_aum desc
             limit 5;
             """)

# %%
avg_nav_per_month =text("""
                        select month, avg(nav) from fact_nav fn
                        join dim_date dd on fn.date_id=dd.date_id
                        groupby month
                        """ )

# %%
sip_yoy_growth = text(""" 
                      select year, sum(amount) from fact_transaction ft 
                      join dim_date dd on ft.date_id = dd.date_id
                      where transaction_type = "SIP"
                      group by year 
                      """)

# %%
tras_by_state = text("""
                     select state, count(*)
                     from fact_transactions
                     group by state
                     """)

# %%
expense_ratio_greater_10precent = text("""
                                       select fund_name, expense_ratio from fact_performance fp
                                       join dim_fund df on fp.fund_id = df.fund_id
                                       where expense_ratio >1;
                                       """)

# %%
highest_nav=text("""select max(nav) from dim_nav;""")

# %%
avg_1yr_return = text("""select month,sum(return_1yr_pct) from fact_performance """)

# %%
top_redumption_funds = text("""select fund_id, sum(amount) from fact_transaction
                            where transaction_type="Redemption
                            group by fund_id
                            oder by sum(amount) desc
                            limit 5""")

# %%
aum_by_month = text("""select month, sum(aum)
                    from fact_aum fa
                    join dim_date dd
                    on fa.date_id=dd.date_id
                    group by month""")

# %%
funds_highest_5yr_return = text(""" select fund_name,return_5yr_pct from fact_performance fp
                                join dim_date dd
                                on fp.date_id =dd.date_id
                                order by return_5yr_pct
                                limit 5;
                                """)

# %%
with engine.connect() as connection:
    res=connection.execute(expense_ratio_greater_10precent)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# OperationalError: no such table: fact_performance
#
# The above exception was the direct cause of the following exception:
#
# ...
