# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df= pd.read_csv("/Users/himanshunautiyal/Desktop/untitled folder/Project/data/raw/10_benchmark_indices.csv")

# %%
df.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
df.sample()
# Out:
#             date index_name  close_value
# 5485  2025-05-26   NIFTY500     27532.55

# %%
df.dtypes
# Out:
# date            object
# index_name      object
# close_value    float64
# dtype: object

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# date           datetime64[ns]
# index_name             object
# close_value           float64
# dtype: object

# %%
## Checking for the duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
## droping the duplicated rows
df.drop_duplicates(inplace=True)

# %%
df.to_csv("/Users/himanshunautiyal/Desktop/untitled folder/Project/data/processed/10_cleaned_benchmark_indices.csv",index=False)
